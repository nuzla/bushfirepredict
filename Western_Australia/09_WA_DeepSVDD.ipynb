# %%
pip install pyod shap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyod in /usr/local/lib/python3.8/dist-packages (1.0.6)
# Requirement already satisfied: shap in /usr/local/lib/python3.8/dist-packages (0.41.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from pyod) (1.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from pyod) (1.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pyod) (3.2.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.8/dist-packages (from pyod) (0.12.2)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.8/dist-packages (from pyod) (0.56.4)
# Requirement already satisfied: scipy>=1.5.1 in /usr/local/lib/python3.8/dist-packages (from pyod) (1.7.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from pyod) (1.2.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.8/dist-packages (from pyod) (1.21.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->pyod) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->pyod) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.8/dist-packages (from numba>=0.51->pyod) (4.13.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->pyod) (3.1.0)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.8/dist-packages (from shap) (21.3)
# Requirement already satisfied: tqdm>4.25.0 in /usr/local/lib/python3.8/dist-packages (from shap) (4.64.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from shap) (1.3.5)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.8/dist-packages (from shap) (1.5.0)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.8/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>20.9->shap) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata->numba>=0.51->pyod) (3.11.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyod) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyod) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pyod) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->shap) (2022.6)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.8/dist-packages (from statsmodels->pyod) (0.5.3)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
import warnings
from pyod.models.deep_svdd import DeepSVDD
from pyod.models.lof import LOF
import matplotlib.pyplot as plt
import seaborn as sn
import shap
from pickle import dump, load

# %% [markdown]
# #### Data Loading

# %%
df=pd.read_pickle('https://drive.google.com/uc?id=1YX0Hpx9G3QZXqmuoXE8A3_C5atpgo81G')

# %%
df.head()
# Out:
#    IDATE       LAT       LON  ELEVATION_m  PPT_mm    TMIN_c   TMEAN_c  \
# 0    0.0  0.250576  0.179574     0.223896     0.0  0.427626  0.447125
# 1    0.0  0.197867  0.189637     0.284137     0.0  0.461583  0.466090
# 2    0.0  0.203466  0.189485     0.330321     0.0  0.454101  0.458352
# 3    0.0  0.203666  0.189536     0.329317     0.0  0.454101  0.458352
# 4    0.0  0.204106  0.189441     0.327309     0.0  0.454101  0.458352
#
#      TMAX_c  TDMEAN_c  lfmc_mean  lfmc_stdv  Mean_Sea_Level_Pressure  \
# 0  0.486874  0.738624   0.107583   0.212526                 0.404444
# 1  0.488730  0.740741   0.194569   0.175128                 0.406667
# 2  0.482100  0.743915   0.210215   0.137647                 0.404444
# 3  0.482100  0.743915   0.194408   0.132680                 0.404444
# 4  0.482100  0.743915   0.269143   0.158312                 0.404444
#
#    Mean_Station_Pressure  Mean_Wind_Speed  Maximum_Sustained_Wind_Speed  \
# 0               0.525210         0.085729                      0.367457
# 1               0.533613         0.073122                      0.367457
# 2               0.532213         0.075139                      0.367457
# 3               0.532213         0.075139                      0.367457
# 4               0.532213         0.075139                      0.367457
#
#    VPD9AM_hpa  VPD3PM_hpa
# 0    0.393151    0.422969
# 1    0.376416    0.411485
# 2    0.377703    0.413445
# 3    0.377703    0.413445
# 4    0.377703    0.413445

# %%
X_train, X_test = train_test_split(df, test_size=0.2, random_state=1, shuffle=False)
#Labels for PyOD 0 = inlier, 1 = outlier 
y_train=np.zeros(X_train.shape[0])
y_test=np.zeros(X_test.shape[0])
print("Train set data size : "+str(X_train.shape))
print("Test set data size : "+str(X_test.shape))
# Out:
# Train set data size : (26640, 17)
# Test set data size : (6660, 17)

# %% [markdown]
# #### Model Training

# %%
estimator=DeepSVDD(c=None, random_state=1, hidden_neurons=[32,32,16])
estimator.fit(X_train)
# Out:
# 833/833 [==============================] - 1s 1ms/step
# Model: "model_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 17)]              0
#
#  dense_18 (Dense)            (None, 32)                544
#
#  dense_19 (Dense)            (None, 32)                1024
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  net_output (Dense)          (None, 16)                512
#
#  tf.math.subtract_11 (TFOpLa  (None, 16)               0
#  mbda)
#
#  tf.math.pow_11 (TFOpLambda)  (None, 16)               0
#
#  tf.math.reduce_sum_11 (TFOp  (None,)                  0
#  Lambda)
#
#  tf.math.reduce_mean_11 (TFO  ()                       0
#  pLambda)
#
#  tf.__operators__.add_11 (TF  ()                       0
#  OpLambda)
#
#  add_loss_11 (AddLoss)       ()                        0
#
# =================================================================
# Total params: 2,080
# Trainable params: 2,080
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 750/750 [==============================] - 3s 3ms/step - loss: 0.7403 - val_loss: 0.2376
# Epoch 2/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.2165 - val_loss: 0.1470
# Epoch 3/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1582 - val_loss: 0.1222
# Epoch 4/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1377 - val_loss: 0.1142
# Epoch 5/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1301 - val_loss: 0.1104
# Epoch 6/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1246 - val_loss: 0.1055
# Epoch 7/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1211 - val_loss: 0.1059
# Epoch 8/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1190 - val_loss: 0.1062
# Epoch 9/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1187 - val_loss: 0.1031
# Epoch 10/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1163 - val_loss: 0.1046
# Epoch 11/100
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1148 - val_loss: 0.1019
# Epoch 12/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1138 - val_loss: 0.1017
# Epoch 13/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1129 - val_loss: 0.1023
# Epoch 14/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1117 - val_loss: 0.1029
# Epoch 15/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1115 - val_loss: 0.1027
# Epoch 16/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1109 - val_loss: 0.1017
# Epoch 17/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1103 - val_loss: 0.1009
# Epoch 18/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1106 - val_loss: 0.1010
# Epoch 19/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1096 - val_loss: 0.1027
# Epoch 20/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1112 - val_loss: 0.1010
# Epoch 21/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1094 - val_loss: 0.1012
# Epoch 22/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1094 - val_loss: 0.1033
# Epoch 23/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1100 - val_loss: 0.1013
# Epoch 24/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1097 - val_loss: 0.1047
# Epoch 25/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1090 - val_loss: 0.1007
# Epoch 26/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1089 - val_loss: 0.0992
# Epoch 27/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1092 - val_loss: 0.1001
# Epoch 28/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1093 - val_loss: 0.0997
# Epoch 29/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.0998
# Epoch 30/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1090 - val_loss: 0.1015
# Epoch 31/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1087 - val_loss: 0.1025
# Epoch 32/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1090 - val_loss: 0.1009
# Epoch 33/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1086 - val_loss: 0.1003
# Epoch 34/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1095 - val_loss: 0.1005
# Epoch 35/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1085 - val_loss: 0.0991
# Epoch 36/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.0986
# Epoch 37/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1087 - val_loss: 0.1021
# Epoch 38/100
# 750/750 [==============================] - 1s 2ms/step - loss: 0.1081 - val_loss: 0.1023
# Epoch 39/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.0988
# Epoch 40/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.1018
# Epoch 41/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1085 - val_loss: 0.1026
# Epoch 42/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.1007
# Epoch 43/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.1002
# Epoch 44/100
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1089 - val_loss: 0.0987
# Epoch 45/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.0991
# Epoch 46/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1088 - val_loss: 0.1027
# Epoch 47/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.1015
# Epoch 48/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.1020
# Epoch 49/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.1017
# Epoch 50/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.1000
# Epoch 51/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.1000
# Epoch 52/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1086 - val_loss: 0.1018
# Epoch 53/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1086 - val_loss: 0.1017
# Epoch 54/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1083 - val_loss: 0.1008
# Epoch 55/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.0995
# Epoch 56/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1085 - val_loss: 0.1000
# Epoch 57/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.0988
# Epoch 58/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.0998
# Epoch 59/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1082 - val_loss: 0.0988
# Epoch 60/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.1012
# Epoch 61/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.1006
# Epoch 62/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1086 - val_loss: 0.1008
# Epoch 63/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.1070
# Epoch 64/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1082 - val_loss: 0.1015
# Epoch 65/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.1020
# Epoch 66/100
# 750/750 [==============================] - 2s 3ms/step - loss: 0.1079 - val_loss: 0.1035
# Epoch 67/100
# 750/750 [==============================] - 3s 4ms/step - loss: 0.1087 - val_loss: 0.1001
# Epoch 68/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1076 - val_loss: 0.1003
# Epoch 69/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.0997
# Epoch 70/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.0990
# Epoch 71/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.1006
# Epoch 72/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1076 - val_loss: 0.1009
# Epoch 73/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.1002
# Epoch 74/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.0985
# Epoch 75/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.0990
# Epoch 76/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1083 - val_loss: 0.0988
# Epoch 77/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.0997
# Epoch 78/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.1005
# Epoch 79/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.0984
# Epoch 80/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.0985
# Epoch 81/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.1006
# Epoch 82/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.1040
# Epoch 83/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.0992
# Epoch 84/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1084 - val_loss: 0.0997
# Epoch 85/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1083 - val_loss: 0.1042
# Epoch 86/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1078 - val_loss: 0.0990
# Epoch 87/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.0992
# Epoch 88/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1082 - val_loss: 0.1014
# Epoch 89/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1083 - val_loss: 0.0985
# Epoch 90/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.0992
# Epoch 91/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1075 - val_loss: 0.1004
# Epoch 92/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1081 - val_loss: 0.1022
# Epoch 93/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.0989
# Epoch 94/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1077 - val_loss: 0.1035
# Epoch 95/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1085 - val_loss: 0.1000
# Epoch 96/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1080 - val_loss: 0.1003
# Epoch 97/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1075 - val_loss: 0.1029
# Epoch 98/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.0984
# Epoch 99/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1079 - val_loss: 0.1016
# Epoch 100/100
# 750/750 [==============================] - 2s 2ms/step - loss: 0.1095 - val_loss: 0.1016
# 833/833 [==============================] - 1s 1ms/step
# DeepSVDD(batch_size=32,
#      c=array([0.21057, 0.1    , 0.1    , 0.38098, 0.1    , 0.1    , 0.14171,
#        0.1    , 0.41569, 0.1    , 0.1    , 0.18047, 0.23332, 0.32813,
#        0.58409, 0.1    ], dtype=float32),
#      contamination=0.1, dropout_rate=0.2, epochs=100,
#      hidden_activation='relu', hidden_neurons=[32, 32, 16],
#      l2_regularizer=0.1, optimizer='adam', output_activation='sigmoid',
#      preprocessing=True, random_state=1, use_ae=False, validation_size=0.1,
#      verbose=1)

# %%
dump(estimator, open('09_WA_DeepSVDD.pkl', 'wb'))

# %% [markdown]
# #### Train set AVG Probability of Being Inlier

# %%
P1=estimator.predict_proba(X_train)[:,0]
print("Training set Mean :  ",round(np.mean(P1),6))
print("Training set STD :  ",round(np.std(P1),6))
# Out:
# 833/833 [==============================] - 1s 2ms/step
# Training set Mean :   0.996799
# Training set STD :   0.009703

# %% [markdown]
# #### Test set AVG Probability of Being Inlier

# %%
P2=estimator.predict_proba(X_test)[:,0]
print("Test set Mean :  ",round(np.mean(P2),6))
print("Test set STD :  ",round(np.std(P2),6))
# Out:
# 209/209 [==============================] - 0s 1ms/step
# Test set Mean :   0.996428
# Test set STD :   0.004834

# %% [markdown]
# #### All set AVG Probability of Being Inlier

# %%
P=np.append(P1,P2)
print("All Mean :  ",round(np.mean(P),6))
print("All STD :  ",round(np.std(P),6))
# Out:
# All Mean :   0.996725
# All STD :   0.008945

# %%
fig, ax = plt.subplots(figsize=(16,10))
im=ax.scatter(x=df.index,y=P,c=np.multiply(P,10).astype(int),s=5)
ax.grid(True)
plt.show()

# %%
#estimator.explain_outlier(1000)

# %% [markdown]
# #### Feature Importance

# %%
warnings.filterwarnings('ignore')
#k_explainer = shap.KernelExplainer(estimator.predict, shap.sample(X_train, random_state=1))
k_explainer = shap.KernelExplainer(estimator.predict, shap.sample(X_train, nsamples=500, random_state=1))
X_test_sample=shap.sample(X_test,random_state=1)
k_shap_values = k_explainer.shap_values(X_test_sample) # More Sample Need more time
warnings.filterwarnings('once')
# Out:
# 16/16 [==============================] - 0s 1ms/step
# WARNING:shap:Using 500 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/100 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 55s 2ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 44s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 44s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 24ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 40s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 25ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 91ms/step
# 32532/32532 [==============================] - 44s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 24ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 40s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 27ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 21ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 16ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 20ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 41s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 24ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 17ms/step
# 32532/32532 [==============================] - 42s 1ms/step
# 1/1 [==============================] - 0s 19ms/step
# 32532/32532 [==============================] - 44s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# 32532/32532 [==============================] - 43s 1ms/step
# 1/1 [==============================] - 0s 18ms/step
# 32532/32532 [==============================] - 42s 1ms/step

# %%
shap.initjs()
shap.summary_plot(k_shap_values, X_test_sample, plot_type="bar")
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.initjs()
shap.summary_plot(k_shap_values, X_test_sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.initjs()
shap.force_plot(k_explainer.expected_value, k_shap_values, X_test_sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='i1G5Y49DZDE7ZW9XHBDJ0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.096, "link": "identity", "featureNames": ["IDATE", "LAT", "LON", "ELEVATION_m", "PPT_mm", "TMIN_c", "TMEAN_c", "TMAX_c", "TDMEAN_c", "lfmc_mean", "lfmc_stdv", "Mean_Sea_Level_Pressure", "Mean_Station_Pressure", "Mean_Wind_Speed", "Maximum_Sustained_Wind_Speed", "VPD9AM_hpa", "VPD3PM_hpa"], "explanations": [{"outValue": -4.163336342344337e-17, "simIndex": 90.0, "features": {"0": {"effect": 0.03629281325766302, "value": 0.7115044247787611}, "1": {"effect": -0.1557257457442611, "value": 0.8678403537041723}, "2": {"effect": 0.1257648839524537, "value": 0.3624712829178458}, "3": {"effect": -0.05925212624954828, "value": 0.5200803212851405}, "4": {"effect": -0.07971833514777008, "value": 0.0}, "5": {"effect": 0.003831879693840126, "value": 0.3556834532374101}, "6": {"effect": 0.0028666177379929178, "value": 0.4167804582005765}, "7": {"effect": 0.023546523114542514, "value": 0.500132590824715}, "8": {"effect": -0.013119869319622616, "value": 0.6391534391534391}, "9": {"effect": -0.042190908143369475, "value": 0.17309335726578393}, "10": {"effect": 0.014198392828576021, "value": 0.13301903148799002}, "11": {"effect": 0.012759262728502101, "value": 0.42666666666666586}, "12": {"effect": 0.0, "value": 0.5154061624649859}, "13": {"effect": 0.0, "value": 0.06505295007564298}, "14": {"effect": 0.024403307984821196, "value": 0.28125}, "15": {"effect": 0.010343303306179927, "value": 0.2299176107106076}, "16": {"effect": 0.0, "value": 0.14789915966386555}}}, {"outValue": -1.3877787807814457e-17, "simIndex": 7.0, "features": {"0": {"effect": -0.015522960343459055, "value": 0.10265486725663717}, "1": {"effect": -0.03354195080950862, "value": 0.8761635881796754}, "2": {"effect": -0.0885376756293817, "value": 0.15645509376166888}, "3": {"effect": 0.013000214284071158, "value": 0.10441767068273092}, "4": {"effect": 0.17234455736695067, "value": 0.11402157164869028}, "5": {"effect": 0.07524541025836695, "value": 0.7620143884892085}, "6": {"effect": -0.10974208046515448, "value": 0.7554240631163708}, "7": {"effect": -0.029622027198634437, "value": 0.7175815433571997}, "8": {"effect": 0.029817352976448087, "value": 0.8613756613756614}, "9": {"effect": 0.004849620146273652, "value": 0.17151947312912513}, "10": {"effect": -0.007120433348083675, "value": 0.1265757116943386}, "11": {"effect": -0.013873630657743705, "value": 0.326666666666668}, "12": {"effect": 0.009157962129850102, "value": 0.602240896358543}, "13": {"effect": -0.020258085623404587, "value": 0.07513867876954111}, "14": {"effect": 0.0, "value": 0.4655172413793104}, "15": {"effect": -0.09286300243588494, "value": 0.8056127703398557}, "16": {"effect": 0.010666729349294565, "value": 0.8736694677871149}}}, {"outValue": 0.0, "simIndex": 18.0, "features": {"0": {"effect": -0.14514485506788355, "value": 0.984070796460177}, "1": {"effect": 0.16027500813749057, "value": 0.3949341465688301}, "2": {"effect": 0.05986227104279827, "value": 0.8112235533868759}, "3": {"effect": 0.04655027374805144, "value": 0.19979919678714858}, "4": {"effect": -0.0630929683203997, "value": 0.0}, "5": {"effect": 0.014661734744824016, "value": 0.5099280575539569}, "6": {"effect": -0.010874616671659279, "value": 0.48475193445607656}, "7": {"effect": 0.008733903359950819, "value": 0.4767966056748873}, "8": {"effect": 0.0, "value": 0.6857142857142857}, "9": {"effect": -0.0367771297161737, "value": 0.17337258332007058}, "10": {"effect": 0.013655429720288936, "value": 0.1324296398041466}, "11": {"effect": -0.04951522340673103, "value": 0.5244444444444447}, "12": {"effect": -0.04541525974708262, "value": 0.4285714285714288}, "13": {"effect": -0.058334946040254965, "value": 0.10489157841654062}, "14": {"effect": 0.0, "value": 0.4267241379310345}, "15": {"effect": 0.009416378216780805, "value": 0.3056127703398558}, "16": {"effect": 0.0, "value": 0.2436974789915966}}}, {"outValue": 5.551115123125783e-17, "simIndex": 82.0, "featur ...

# %%
feature_names = X_train.columns
rf_resultX = pd.DataFrame(k_shap_values, columns = feature_names)
vals = np.abs(rf_resultX.values).mean(0)
shap_importance = pd.DataFrame(list(zip(feature_names, vals)),
                                  columns=['col_name','feature_importance_vals'])
#shap_importance.sort_values(by=['feature_importance_vals'], ascending=False, inplace=True)
shap_importance
# Out:
#                         col_name  feature_importance_vals
# 0                          IDATE                 0.037339
# 1                            LAT                 0.124500
# 2                            LON                 0.103716
# 3                    ELEVATION_m                 0.029720
# 4                         PPT_mm                 0.074240
# 5                         TMIN_c                 0.053043
# 6                        TMEAN_c                 0.035714
# 7                         TMAX_c                 0.041813
# 8                       TDMEAN_c                 0.012808
# 9                      lfmc_mean                 0.032529
# 10                     lfmc_stdv                 0.008044
# 11       Mean_Sea_Level_Pressure                 0.029443
# 12         Mean_Station_Pressure                 0.042395
# 13               Mean_Wind_Speed                 0.018339
# 14  Maximum_Sustained_Wind_Speed                 0.021558
# 15                    VPD9AM_hpa                 0.014768
# 16                    VPD3PM_hpa                 0.007653
